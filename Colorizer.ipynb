# %%
"""
Lab 3 – Image Colorization (TNM112)
Fully-convolutional U-Net trained to colorize grayscale images
Dataset: CIFAR-10
Framework: TensorFlow / Keras
"""

# =============================
# 1. Imports & setup
# =============================
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# Reproducerbarhet
tf.random.set_seed(42)
np.random.seed(42)

# =============================
# 2. Ladda och preprocessa CIFAR-10
# =============================
(x_train, _), (x_test, _) = tf.keras.datasets.cifar10.load_data()

# Normalisera till [0, 1]
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0


# =============================
# 3. Skapa gråskale-input
# =============================
def rgb_to_gray(images):
    """Konverterar RGB-bilder till 1-kanals gråskala"""
    return tf.image.rgb_to_grayscale(images)

x_train_gray = rgb_to_gray(x_train)
x_test_gray = rgb_to_gray(x_test)


# =============================
# 4. Bygg U-Net-modell
# =============================
def build_unet():
    inputs = layers.Input(shape=(32, 32, 1))

    # ----- Encoder -----
    c1 = layers.Conv2D(64, 3, activation="relu", padding="same")(inputs)
    c1 = layers.Conv2D(64, 3, activation="relu", padding="same")(c1)
    p1 = layers.MaxPooling2D()(c1)

    c2 = layers.Conv2D(128, 3, activation="relu", padding="same")(p1)
    c2 = layers.Conv2D(128, 3, activation="relu", padding="same")(c2)
    p2 = layers.MaxPooling2D()(c2)

    # ----- Bottleneck -----
    b = layers.Conv2D(256, 3, activation="relu", padding="same")(p2)
    b = layers.Conv2D(256, 3, activation="relu", padding="same")(b)

    # ----- Decoder -----
    u1 = layers.UpSampling2D()(b)
    u1 = layers.Concatenate()([u1, c2])
    c3 = layers.Conv2D(128, 3, activation="relu", padding="same")(u1)
    c3 = layers.Conv2D(128, 3, activation="relu", padding="same")(c3)

    u2 = layers.UpSampling2D()(c3)
    u2 = layers.Concatenate()([u2, c1])
    c4 = layers.Conv2D(64, 3, activation="relu", padding="same")(u2)
    c4 = layers.Conv2D(64, 3, activation="relu", padding="same")(c4)

    # ----- Output -----
    outputs = layers.Conv2D(3, 1, activation="sigmoid")(c4)

    return models.Model(inputs, outputs)


model = build_unet()
model.summary()


# =============================
# 5. Kompilera modellen
# =============================

# # MSE = Mean Squared Error (L2-loss)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="mse",          # L2-loss
    metrics=["mae"]
)
# MAE = Mean Absolute Error (L1-loss)
# model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
#     loss="mae",          # L2-loss
#     metrics=["mae"]
# )


# =============================
# 6. Träna modellen
# =============================
history = model.fit(
    x_train_gray,
    x_train,
    validation_split=0.1,
    epochs=50,           # öka för bättre resultat
    batch_size=64,
    verbose=1
)

# =============================
# Visualisera data från träningen
# =============================
plt.plot(history.history["loss"], label="Train MSE")
plt.plot(history.history["val_loss"], label="Val MSE")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.show()

# =============================
# 7. Utvärdering
# =============================
model.evaluate(x_test_gray, x_test)


# =============================
# 8. Visualisera resultat
# =============================
def visualize_colorization(gray, pred, gt, n=5):
    """
    Rad 1: Grayscale input
    Rad 2: Modellens prediktion
    Rad 3: Ground truth
    """
    plt.figure(figsize=(3 * n, 8))

    for i in range(n):
        # --- Rad 1: Input ---
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(gray[i].numpy().squeeze(), cmap="gray")
        
        # Istället för plt.axis("off"), dölj bara ticks och ram:
        plt.xticks([]) 
        plt.yticks([])
        for spine in ax.spines.values():
            spine.set_visible(False)
            
        if i == 0:
            plt.ylabel("Input", fontsize=12)

        # --- Rad 2: Prediktion ---
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(pred[i])
        
        plt.xticks([])
        plt.yticks([])
        for spine in ax.spines.values():
            spine.set_visible(False)
            
        if i == 0:
            plt.ylabel("Predicted", fontsize=12)

        # --- Rad 3: Ground truth ---
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(gt[i])
        
        plt.xticks([])
        plt.yticks([])
        for spine in ax.spines.values():
            spine.set_visible(False)
            
        if i == 0:
            plt.ylabel("Ground truth", fontsize=12)

    plt.tight_layout()
    plt.show()

# Prediktera och visa exempel
preds = model.predict(x_test_gray[:5])
visualize_colorization(x_test_gray[:5], preds, x_test[:5])


# =============================
# 9. Spara modellen (valfritt)
# =============================
# model.save("colorization_unet_cifar10")
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 32, 32, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 32, 32,    │        640 │ input_layer_4[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 32, 32,    │     36,928 │ conv2d_44[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 16, 16,    │          0 │ conv2d_45[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 16, 16,    │     73,856 │ max_pooling2d_8[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 16, 16,    │    147,584 │ conv2d_46[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 8, 8, 128) │          0 │ conv2d_47[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_9[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ conv2d_48[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 16, 16,    │          0 │ conv2d_49[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 16, 16,    │          0 │ up_sampling2d_8[… │
# │ (Concatenate)       │ 384)              │            │ conv2d_47[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 16, 16,    │    442,496 │ concatenate_8[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 16, 16,    │    147,584 │ conv2d_50[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 32, 32,    │          0 │ conv2d_51[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 32, 32,    │          0 │ up_sampling2d_9[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_45[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 32, 32,    │    110,656 │ concatenate_9[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 32, 32,    │     36,928 │ conv2d_52[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 32, 32, 3) │        195 │ conv2d_53[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,882,115 (7.18 MB)
#  Trainable params: 1,882,115 (7.18 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 34s 41ms/step - loss: 0.0144 - mae: 0.0803 - val_loss: 0.0098 - val_mae: 0.0644
# Epoch 2/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 25s 36ms/step - loss: 0.0058 - mae: 0.0492 - val_loss: 0.0066 - val_mae: 0.0515
# Epoch 3/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0055 - mae: 0.0477 - val_loss: 0.0060 - val_mae: 0.0495
# Epoch 4/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 35ms/step - loss: 0.0053 - mae: 0.0468 - val_loss: 0.0059 - val_mae: 0.0487
# Epoch 5/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - loss: 0.0052 - mae: 0.0462 - val_loss: 0.0058 - val_mae: 0.0492
# Epoch 6/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0051 - mae: 0.0458 - val_loss: 0.0054 - val_mae: 0.0474
# Epoch 7/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0050 - mae: 0.0454 - val_loss: 0.0055 - val_mae: 0.0476
# Epoch 8/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0049 - mae: 0.0450 - val_loss: 0.0053 - val_mae: 0.0463
# Epoch 9/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0048 - mae: 0.0445 - val_loss: 0.0052 - val_mae: 0.0463
# Epoch 10/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0047 - mae: 0.0441 - val_loss: 0.0052 - val_mae: 0.0457
# Epoch 11/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0046 - mae: 0.0439 - val_loss: 0.0052 - val_mae: 0.0463
# Epoch 12/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0045 - mae: 0.0434 - val_loss: 0.0055 - val_mae: 0.0473
# Epoch 13/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0044 - mae: 0.0430 - val_loss: 0.0055 - val_mae: 0.0474
# Epoch 14/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0043 - mae: 0.0427 - val_loss: 0.0056 - val_mae: 0.0474
# Epoch 15/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0042 - mae: 0.0424 - val_loss: 0.0053 - val_mae: 0.0459
# Epoch 16/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0041 - mae: 0.0418 - val_loss: 0.0056 - val_mae: 0.0473
# Epoch 17/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.0040 - mae: 0.0415 - val_loss: 0.0054 - val_mae: 0.0469
# Epoch 18/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 0.